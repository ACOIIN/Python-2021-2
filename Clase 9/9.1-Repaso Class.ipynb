# %% [markdown]
# # Breve repaso de clases en Python
# Las clases son entidades que guardan datos (**atributos**) y tienen acciones asociadas a ellas (**métodos**).
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Hagamos un Pokemon
# A contionuación vamos a crear la clase pokemon.

# %%
class Pokemon():
    
    def __init__(self, name, type, ps, ataque):
        self.name =         # le damos nombre al pokemon
        self.ps =           # puntos de vida del pokemon
        self.ataque =       # daño de ataque del pokemon
        self.type =         # el tipo determina que tan eficaz sera su ataque contra otros pokemon
    
    def atacar(self, oponente):       # metodo para atacar a otro pokemon
        pass

# %% [markdown]
# Probemos la clase

# %%
Squirtle = Pokemon('Squirtle', 100, 5, 'agua')
Bulbasaur = Pokemon('Bulbasaur', 100, 10, 'planta')

Bulbasaur.ataque(Squirtle)
Squirtle.ataque(Bulbasaur)
