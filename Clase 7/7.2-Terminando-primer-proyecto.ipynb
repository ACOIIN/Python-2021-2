# %% [markdown]
# # Proyecto 1 - Batalla Naval
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 1 Vista general del avance
# Veamos cómo deberían ir con el proyecto hasta ahora.

# %% [markdown]
# ## 2 ¿Qué falta?

# %% [markdown]
# - Generar tableros con barcos
# - Simular turno de la computadora
# - Implementar fin del juego
# - Definir puntajes
# - Imprimir ranking
# - Guardar mejores marcas
